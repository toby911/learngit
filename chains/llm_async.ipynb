# %%
import asyncio
import time
import sys, os, ipykernel, pathlib
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
current_working_directory = os.getcwd()
sys.path.append(os.path.dirname(current_working_directory))
nb_path = pathlib.Path(os.path.abspath(ipykernel.__file__)).parent.resolve(strict=True)
from models.glm_api import glm_api as glm

llm = glm()


def generate_serially():
    prompt = PromptTemplate(
        input_variables=["product"],
        template="What is a good name for a company that makes {product}?",
    )
    chain = LLMChain(llm=llm, prompt=prompt)
    for _ in range(5):
        resp = chain.run(product="toothpaste")
        print(resp)


async def async_generate(chain):
    resp = await chain.arun(product="toothpaste")
    print(resp)


async def generate_concurrently():
    prompt = PromptTemplate(
        input_variables=["product"],
        template="What is a good name for a company that makes {product}?",
    )
    chain = LLMChain(llm=llm, prompt=prompt)
    tasks = [async_generate(chain) for _ in range(5)]
    await asyncio.gather(*tasks)

s = time.perf_counter()
# If running this outside of Jupyter, use asyncio.run(generate_concurrently())
await generate_concurrently()
elapsed = time.perf_counter() - s
print('\033[1m' + f"Concurrent executed in {elapsed:0.2f} seconds." + '\033[0m')

s = time.perf_counter()
generate_serially()
elapsed = time.perf_counter() - s
print('\033[1m' + f"Serial executed in {elapsed:0.2f} seconds." + '\033[0m')
# Out:
# Here are a few suggestions for a good name for a company that makes toothpaste:
#
# 1. Toothpaste Factory
# 2.  toothpaste Inc.
# 3. ToothpasteUSA
# 4. Toothpaste制造公司
# 5. toothpaste制造厂
# 6. Toothpaste制造有限公司
# 7. Toothpaste制造股份有限公司
# 8. Toothpaste制造局
# 9.  toothpaste制造商
# 10. Toothpaste制造公司
# An HTTP error occurred:
# 抱歉，AI发生了错误，没有返回!
# An HTTP error occurred:
# 抱歉，AI发生了错误，没有返回!
# An HTTP error occurred:
# 抱歉，AI发生了错误，没有返回!
# An HTTP error occurred:
# 抱歉，AI发生了错误，没有返回!
# Concurrent executed in 5.29 seconds.
# A good name for a company that makes toothpaste could be something that reflects the product's benefits and features, such as "Toothpaste Protects" or "Toothpaste Refreshes." Other potential names could include "Toothpaste Sensitive," "Toothpaste Secure," or "Toothpaste Refreshed." Ultimately, the best name for the company will depend on the specific products and target market, so it's important to do some research and consider a variety of options to find the one that best fits.
# Here are a few suggestions for a good name for a company that makes toothpaste:
#
# 1. Toothpaste Factory
# 2.  toothpaste Inc.
# 3. ToothpasteUSA
# 4. Toothpaste Manufacturing Company
# 5. Toothpaste Solutions
# 6. Toothpaste Pro
# 7. toothpasteHub
# 8. Toothpaste Master
# 9. Toothpaste Time
# 10. Toothpaste Vault.
# Here are a few suggestions for a good name for a company that makes toothpaste:
#
# 1. Toothpaste Factory
# 2.  toothpaste Emporium
# 3. Toothpaste Universe
# 4. Toothpaste Town
# 5. ToothpasteUSA
# 6. Toothpaste Masterpiece
# 7. Toothpaste Perfection
# 8. Toothpaste Treasures
# 9. Toothpaste Vault
# 10. Toothpaste Delight
#
# I hope these suggestions are helpful!
# A good name for a company that makes toothpaste could be something that reflects the product's benefits and features, such as "Toothpaste Protects" or "Toothpaste Refreshes." Other potential names could include "Toothpaste Sensitive," "Toothpaste Secure," or "Toothpaste Refreshed." Ultimately, the best name for the company will depend on the specific product and target market, so it's important to do some research and consider a few different options before making a decision.
# Here are a few suggestions for a good name for a company that makes toothpaste:
#
# 1. ToothpasteUSA
# 2. toothpastePro
# 3. ToothpasteWorks
# 4. ToothpasteTone
# 5. toothpasteLife
# 6. ToothpasteTone
# 7. toothpasteWorks
# 8. ToothpasteUSA
# 9. ToothpasteTone
# 10. toothpasteLife
#
# I hope these suggestions are helpful!
# Serial executed in 27.06 seconds.
